# %% [markdown]
# Scrapy je besplatan i *open-source* Python okvir za *web-crawling*. Pruža alate koji su potrebni za učinkovito *povlačenje* podataka s web stranica, njihovu obradu te pohranu u željenom formatu i strukturi.
#
# > Zadatak: *web-scrapanje* Youtube web stranice
#
# *   Link: https://www.youtube.com/
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1c8Ldn6CP0l5YqEgmVP7gDp-7tinJZnLD" width="300">
# <img src="https://drive.google.com/uc?export=view&id=1XbiFUMckMlbY4-hi0KrxSLGXOREIm65m" width="200">
# </center>

# %% [markdown]
# > Instalacija okvira Scrapy

# %%
pip install scrapy

# %%
# %cd /content/drive/MyDrive/yt_scrapy
# Out:
# /content/drive/MyDrive/yt_scrapy

# %% [markdown]
# > *Importanje* scrapy biblioteke i ostalih potrebnih modula

# %%
import scrapy 
from scrapy.crawler import CrawlerProcess
import json

# %% [markdown]
# > Kreiranje scrapy Spidera za *crawling* stranice i izvlačenje podataka
#
#                   *   YoutubeSpider je klasa, nasljeđuje se od scrapy.Spidera
#                   *   parse() je zadana callback metoda
#                   *   yield

# %%
class YoutubeSpider(scrapy.Spider):
    
    name = "YoutubeSpider"
    
    start_urls = []
    #start_urls = ['https://www.youtube.com/watch?v=Tc0tLGWIqxA']

    input_file = open('yt_links.txt', 'r')

    for link in input_file:
      start_urls.append(link)

    def parse(self, response):
        """parse data from urls"""
        
        #print(response.text)

        yield {
            'title': response.xpath('//meta[@name="title"]/@content').get(),
            'datePublished': response.xpath('//meta[@itemprop="datePublished"]/@content').get(),
            'genre': response.xpath('//meta[@itemprop="genre"]/@content').get(),
            'publisher' : response.xpath('//link[@itemprop="name"]/@content').get(),
            'viewsCount' : response.xpath('//meta[@itemprop="interactionCount"]/@content').get()
        }

# %% [markdown]
# > HTML Youtube stranice

# %% [markdown]
# <center><img src="https://drive.google.com/uc?export=view&id=1Yc05Bn7xCG7qJLwzB3nijpweNH07Drb5"></center>

# %% [markdown]
# > Pokretanje scrapy Spidera iz skripte
#
#         *   Klasa CrawlerProcess modula Crawler
#         *   Instancira se settings objekt

# %%
process = CrawlerProcess(
    settings=
    {
        'FEEDS': 
     {
        'yt_data.csv': 
        {
            'format': 'csv',
            'overwrite': True
        }
    }
})
# Out:
# 2021-11-21 15:40:24 [scrapy.utils.log] INFO: Scrapy 2.5.1 started (bot: scrapybot)
# 2021-11-21 15:40:24 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.7.0, Python 3.7.12 (default, Sep 10 2021, 00:21:48) - [GCC 7.5.0], pyOpenSSL 21.0.0 (OpenSSL 1.1.1l  24 Aug 2021), cryptography 35.0.0, Platform Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# 2021-11-21 15:40:24 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor

# %% [markdown]
# > Pokretanje YoutubeSpidera

# %%
process.crawl(YoutubeSpider)
process.start()
# Out:
# 2021-11-21 15:40:29 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2021-11-21 15:40:29 [scrapy.extensions.telnet] INFO: Telnet Password: 79764fcffe1b147a
# 2021-11-21 15:40:29 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2021-11-21 15:40:29 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
# ...

# %%
#print(response.text)
# Out:
# 2021-11-21 14:38:06 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2021-11-21 14:38:06 [scrapy.extensions.telnet] INFO: Telnet Password: efbf647480a1ec05
# 2021-11-21 14:38:06 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2021-11-21 14:38:06 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
# ...

# %% [markdown]
# > Skripta s JSON objektom koji sadrži podatake o videozapisu u responsu

# %%
obj = json.loads(response.css('script::text').extract()[30][20:-1])

#print(obj)
# Out:
# 2021-11-21 14:51:59 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2021-11-21 14:51:59 [scrapy.extensions.telnet] INFO: Telnet Password: 2bbc695e1bb41229
# 2021-11-21 14:51:59 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2021-11-21 14:51:59 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
# ...

# %%
# spremanje podataka o videozapisu u varijable

title = obj["contents"]["twoColumnWatchNextResults"]['results']['results']['contents'][0]['videoPrimaryInfoRenderer']['title']['runs'][0]['text']
          
viewCount = obj["contents"]["twoColumnWatchNextResults"]['results']['results']['contents'][0]['videoPrimaryInfoRenderer']['viewCount']['videoViewCountRenderer']['viewCount']['simpleText'][:-6]

likesCount = obj["contents"]["twoColumnWatchNextResults"]['results']['results']['contents'][0]['videoPrimaryInfoRenderer']['videoActions']['menuRenderer']['topLevelButtons'][0]['toggleButtonRenderer']['defaultText']['accessibility']['accessibilityData']['label'][:-6]

dislikesCount = obj["contents"]["twoColumnWatchNextResults"]['results']['results']['contents'][0]['videoPrimaryInfoRenderer']['videoActions']['menuRenderer']['topLevelButtons'][1]['toggleButtonRenderer']['defaultText']['accessibility']['accessibilityData']['label'][:-8]

song = obj["contents"]["twoColumnWatchNextResults"]['results']['results']['contents'][1]['videoSecondaryInfoRenderer']['metadataRowContainer']['metadataRowContainerRenderer']['rows'][3]['metadataRowRenderer']['contents'][0]['simpleText']

artist = obj["contents"]["twoColumnWatchNextResults"]['results']['results']['contents'][1]['videoSecondaryInfoRenderer']['metadataRowContainer']['metadataRowContainerRenderer']['rows'][4]['metadataRowRenderer']['contents'][0]['simpleText']

album = obj["contents"]["twoColumnWatchNextResults"]['results']['results']['contents'][1]['videoSecondaryInfoRenderer']['metadataRowContainer']['metadataRowContainerRenderer']['rows'][5]['metadataRowRenderer']['contents'][0]['simpleText']

# %%
# yield novog rječnika
yield {
    'title': title,
    'song' : song,
    'artist': artist,
    'album' : album,
    'viewsCount': viewCount,
    'likesCount': likesCount,
    'dislikesCount': dislikesCount
    }

# %% [markdown]
# > ❗ Problem: objekt ne sadrži istoimenovane ključeve (ili uopće ne sadrži neki od ključeva) za svaki videozapis ❗

# %%
# primjer kada nisu istoimenovani ključevi

#prvi videozapis
artist = obj["contents"]["twoColumnWatchNextResults"]['results']['results']['contents'][1]['videoSecondaryInfoRenderer']['metadataRowContainer']['metadataRowContainerRenderer']['rows'][4]['metadataRowRenderer']['contents'][0]['text']

#drugi videozapis
artist = obj["contents"]["twoColumnWatchNextResults"]['results']['results']['contents'][1]['videoSecondaryInfoRenderer']['metadataRowContainer']['metadataRowContainerRenderer']['rows'][4]['metadataRowRenderer']['contents'][0]['simpleText']

# %% [markdown]
# > Dva videozapisa, npr. jedan se odnosi na video spot pjesme, a drugi na spremanje recepta
#
#               *   U tom slučaju ne mogu  se dohvatiti podatci o npr. artist ili song za drugi videozapise jer videozapisi nisu istog tipa

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1pbPTppkaTw-3bOfiUN5UuvnQSHC3CKe8" width="100">
#
# >  Importanje podataka yt_data.csv datoteke pomoću pandasa

# %%
import pandas as pd

# %%
yt_data = pd.read_csv('yt_data.csv')

# %%
yt_data.columns = ['Title', 'Date published', 'Genre', 'Publisher', 'Views count']

# %% [markdown]
# > Prikaz dataFrame okvira s podacima

# %%
yt_data
# Out:
#                                                 Title  ... Views count
# 0      Demi Lovato - Sorry Not Sorry (Official Video)  ...   488746489
# 1             Deep in the heart of Texas - Gene Autry  ...      107264
# 2                                      joji - will he  ...    67928730
# 3   Fitz And The Tantrums - Out Of My League [Offi...  ...    21164846
# 4                         Yiruma - River Flows in You  ...    36792370
# 5   Ellie Goulding - Love Me Like You Do - Fifty S...  ...    87503435
# 6            Daniel Caesar - Best Part (feat. H.E.R.)  ...   106512232
# 7   Martin Garrix & Dua Lipa - Scared To Be Lonely...  ...   651873423
# 8   Rick Nelson & The Stone Canyon Band - Garden P...  ...       16289
# 9          Donna Summer - Last Dance (Single Version)  ...        1204
# 10                                 Rihanna - Man Down  ...   829869653
# 11           Lauv - I Like Me Better [Official Audio]  ...   304343191
# ...
